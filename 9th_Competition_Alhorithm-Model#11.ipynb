# %% [markdown]
# # <font color=BLUE size=10> 9ª Competição FLAI de
# # <font color=BLUE size=12> MACHINE LEARNING
#
# ***
# **Author**: [Camila Maestrelli](https://www.linkedin.com/in/camila-maestrelli-leobons/)
#
# Este notebook é relativo à Competição de Machine Learning da Flai -

# %% [markdown]
# ## <b>Etapas do projeto: </b>
#
# ### 1. Definição do problema
# ### 2. Importação dos dados
# ### 3. Entendimento dos dados
# ### 4. Limpeza dos dados
# ### 5. Análise exploratória
# ### 6. Pré-processamento
# ### 7. Algoritmo e criação do modelo
# ### 8. Interpretação dos resultados e avaliação dos modelos

# %% [markdown]
# ## <font color=green> <b> 1. Definição do problema </b>
#
# #### <b> Objetivo: </b>
#
# * Prever a demanda de aluguéis de bicicleta a partir de variáveis de clima e dia, obtendo o menor valor de RMSE

# %% [markdown]
# ## <font color=green> <b> 2. Importação dos dados </b>

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 100)

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sv

# ANOVA
#!pip install statsmodels
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import scipy.stats as stats

# Machine Learning library
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import VotingRegressor

#!pip install lightgbm
from lightgbm.sklearn import LGBMRegressor
#!pip install xgboost
from xgboost import XGBRegressor

from sklearn.model_selection import cross_validate, RepeatedKFold, KFold, cross_val_predict
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion


from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler # used when there are many outliers
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import FunctionTransformer

#!pip install category_encoders
import category_encoders as ce   

from sklearn.impute import SimpleImputer, KNNImputer      
from sklearn.compose import ColumnTransformer
from sklearn.compose import TransformedTargetRegressor

#metrics
from sklearn.metrics import mean_absolute_error , r2_score, mean_squared_error

import warnings
from datetime import datetime

import joblib

# %%
train_url = 'https://raw.githubusercontent.com/camilamaestrelli/Demand-Forecasting-Regression_Competition/main/treino.csv'
test_url = 'https://raw.githubusercontent.com/camilamaestrelli/Demand-Forecasting-Regression_Competition/main/teste.csv'

treino = pd.read_csv(train_url)
teste = pd.read_csv(test_url)

display(treino.head())
treino.shape
# Out:
#    hora      dia feriado    estação  temperatura  chuva  umidade   sol  \
# 0    16   sábado     não      verão         39.4    0.0     61.1  2.19
# 1    21    sexta     não  primavera         22.2    0.0     63.3  0.00
# 2    16  segunda     não      verão         40.5    0.0     52.8  2.51
# 3     7  segunda     sim     outono         25.6    0.0     70.9  0.00
# 4     9  segunda     não      verão         39.9    0.0     58.1  1.69
#
#   visibilidade  vento  aluguéis
# 0        92.0%   3.49      1318
# 1        32.0%   2.89       686
# 2        93.0%   3.97       831
# 3        97.0%   1.09        15
# 4        62.0%   1.09       865
# (4500, 11)

# %%
treino['visibilidade'] = treino['visibilidade'].apply(lambda x: x.split('%')[0])
treino['visibilidade'] = pd.to_numeric(treino['visibilidade'])
treino.visibilidade = treino.visibilidade / 100

teste['visibilidade'] = teste['visibilidade'].apply(lambda x: x.split('%')[0])
teste['visibilidade'] = pd.to_numeric(teste['visibilidade'])
teste.visibilidade = teste.visibilidade / 100

# %%
treino.feriado = treino.feriado.map({'sim': 1, 'não': 0})
teste.feriado = teste.feriado.map({'sim': 1, 'não': 0})

# %%
dict_dia = {'domingo': 1,
            'segunda': 2,
            'terça': 3,
            'quarta': 4,
            'quinta': 5,
            'sexta': 6, 
            'sábado': 7}



treino.dia = treino.dia.map(dict_dia)
teste.dia = teste.dia.map(dict_dia)

# %%
dict_estacao = {'inverno': 1,
                    'primavera': 2,
                    'outono': 3,
                    'verão': 4,
                   }


dict_estacao_reverso = {1: 'inverno',
                    2: 'primavera',
                    3: 'outono',
                    4: 'verão',
                   }


treino['estação'] = treino['estação'].map(dict_estacao)
teste['estação'] = teste['estação'].map(dict_estacao)

# %%
np.sqrt(treino.eval('''
    teste = temperatura * visibilidade * sol * vento * hora / umidade
    teste_final = (teste - aluguéis) ** 2
''')['teste_final'].mean())
# Out:
# 960.2251272166366

# %%
treino
# Out:
#       hora  dia  feriado  estação  temperatura  chuva  umidade   sol  \
# 0       16    7        0        4         39.4    0.0     61.1  2.19
# 1       21    6        0        2         22.2    0.0     63.3  0.00
# 2       16    2        0        4         40.5    0.0     52.8  2.51
# 3        7    2        1        3         25.6    0.0     70.9  0.00
# 4        9    2        0        4         39.9    0.0     58.1  1.69
# ...    ...  ...      ...      ...          ...    ...      ...   ...
# 4495     6    6        0        4         30.4    0.0     84.5  0.03
# 4496    16    4        0        3         28.5    0.0     48.3  0.87
# 4497    15    6        0        2         35.1    0.0     37.0  2.20
# 4498    18    1        0        3         32.7    0.0     85.2  0.18
# 4499    15    3        0        1         22.8    0.0     54.3  0.39
#
#       visibilidade  vento  aluguéis
# 0             0.92   3.49      1318
# 1             0.32   2.89       686
# 2             0.93   3.97       831
# 3             0.97   1.09        15
# 4             0.62   1.09       865
# ...            ...    ...       ...
# 4495          0.13   1.57       723
# 4496          0.67   3.49      1151
# 4497          0.95   3.49      1321
# 4498          0.17   3.85       533
# 4499          0.40   1.21       411
#
# [4500 rows x 11 columns]

# %% [markdown]
# ## <font color=green> <b> 6. Pré-processamento </b>

# %% [markdown]
# # Transformações

# %% [markdown]
# ### Funções para transformação

# %% [markdown]
# * Função para criar coluna `dia útil`

# %%
def aux_dia_util(df):
    df['dia_util'] = df[['feriado', 'dia']].apply(lambda x: 
                                                  0 if ((x.feriado == 1) or (x.dia == 1) or (x.dia == 7)) 
                                                  else 1, axis = 1)   
    print('dia util')
    return df[['dia_util']]

func_dia_util = FunctionTransformer(aux_dia_util, check_inverse=False)

###############################################################################################################################


def aux_dia_util(x):
    if (x['feriado'] == 1) or (x['dia'] == 1 or x['dia'] == 7):
        return 0
    else:
        return 1
    
def dados_dia_util(df):
    df['dia_util'] = df[['feriado', 'dia']].apply(aux_dia_util, axis = 1)   
    return df

treino['dia_util'] = treino[['feriado', 'dia']].apply(aux_dia_util, axis = 1)   
teste['dia_util'] = teste[['feriado', 'dia']].apply(aux_dia_util, axis = 1)

# %% [markdown]
# * Funções para criar colunas `horas pico`

# %%
def aux_horas_pico_manha(df):
    df['horas_pico_manha'] = df.hora.map(lambda x: 1 if ((x >= 7) and (x <= 9)) else 0)
    print('pico manha')
    return df[['horas_pico_manha']]
    
func_pico_manha = FunctionTransformer(aux_horas_pico_manha, check_inverse=False)
    
def aux_horas_pico_tarde(df):
    df['horas_pico_tarde'] = df.hora.map(lambda x: 1 if ((x >= 17) and (x <= 19)) else 0)
    print('pico tarde')
    return df[['horas_pico_tarde']]

func_pico_tarde = FunctionTransformer(aux_horas_pico_tarde, check_inverse=False)

def aux_horas_picos(df):
    df['horas_picos'] = df[['hora', 'dia_util', 'dia']].apply(lambda x: 1 if ((((x.dia == 18) or (x.dia == 8)) and x.dia_util == 1) or ((x.dia == 1) and (x.hora == 18)) or ((x.dia == 7) and ( 15 <=x.hora <= 18))) else 0, 
                                                       axis=1)
    print('picos')
    return df[['horas_picos']]

func_picos = FunctionTransformer(aux_horas_picos, check_inverse=False)

# %% [markdown]
# * Função para criar coluna `horas vale`

# %%
def aux_horas_vale(df):
    df['horas_vale'] = df.hora.map(lambda x: 1 if ((x >= 1) and (x <= 6)) else 0)
    print('vale')
    return df[['horas_vale']]

func_horas_vale = FunctionTransformer(aux_horas_vale, check_inverse=False)

# %% [markdown]
# * Função para criar coluna `período do dia`

# %%
def aux_periodo(x):
    
    if x < 6:
        return 0 # madrugada
    elif x < 12:
        return 1 # manhã
    elif x < 18:
        return 2 # tarde
    else:
        return 3 # noite

def aux_periodo_dia(df):
    df['periodo_dia'] = df.hora.map(aux_periodo)
    print('periodo do dia')
    return df[['periodo_dia']]

func_periodo_dia = FunctionTransformer(aux_periodo_dia, check_inverse=False)

# %% [markdown]
# * Funções para trasnformação das variáveis contínuas

# %%
# transformações para as colunas numéricas

from sklearn.base import TransformerMixin, BaseEstimator

class CustomInverser(BaseEstimator, TransformerMixin):
    def __init__(self, value = 1):
        self.value = value
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        colunas = X.columns
        X[colunas] = np.divide(self.value, X[colunas])
        X.fillna(0, inplace=True)
        return X
    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

    
    
def aux_inverso(df):
    coluna = df.columns[0]
    df['inverso_'+coluna] = np.divide(1, df[coluna])
    df.fillna(0, inplace=True)

    print('inverso ', coluna)
    return df[['inverso_'+coluna]]

def aux_raiz(df):
    coluna = df.columns[0]
    df['raiz_'+coluna] = np.sqrt(df[coluna])

    print('raiz ', coluna)
    return df[['raiz_'+coluna]]

def aux_inverso_raiz(df):
    coluna = df.columns[0]
    df['inverso_raiz_'+coluna] = np.divide(1, np.sqrt(df[coluna]))
    df.fillna(0, inplace=True)

    print('inverso da raiz ', coluna)
    return df[['inverso_raiz_'+coluna]]

# para variáveis numéricas
func_inverso = FunctionTransformer(aux_inverso, check_inverse=False)
func_raiz = FunctionTransformer(aux_raiz, check_inverse=False)
func_inverso_raiz = FunctionTransformer(aux_inverso_raiz, check_inverse=False)

# %%
# feature: vento
top_vento = treino['vento'].quantile(0.975)


def aux_vento(df):
    
    df.loc[df['vento']>top_vento] = top_vento
    print('auxiliar vento')
    return df

func_vento = FunctionTransformer(aux_vento, check_inverse=False)

# %%
# feature: chuva
top_chuva = 10

def aux_chuva(df):
    
    df.loc[df['chuva']>top_chuva] = top_chuva
    print('auxiliar chuva')
    return df

func_chuva = FunctionTransformer(aux_chuva, check_inverse=False)

# %%
# feature: chuva


def aux_chuva_binario(df):
    df['chuva'] = df['chuva'].map(lambda x: (0, 1)[x > 0])
    return df
    
#    df.loc[df['chuva']>0] = 1
#    print('auxiliar chuva binario')
#    return df

func_chuva_bin = FunctionTransformer(aux_chuva_binario, check_inverse=False)


def aux_sol_binario(df):
    df['sol'] = df['sol'].map(lambda x: (0, 1)[x > 0])
    return df

func_sol_bin = FunctionTransformer(aux_sol_binario, check_inverse=False)

# %%
# feature: umidade
bottom_umidade = treino.umidade.quantile(0.025)


def aux_umidade(df):
    
    df.loc[df['umidade']<bottom_umidade] = bottom_umidade
    print('auxiliar umidade')
    return df

func_umidade = FunctionTransformer(aux_umidade, check_inverse=False)

# %%
# feature: temperatura
top_temperatura = treino['temperatura'].quantile(0.975)

bottom_temperatura = treino['temperatura'].quantile(0.025)

def aux_temperatura(df):
    
    df.loc[df['temperatura']<bottom_temperatura] = bottom_temperatura
    print('auxiliar temperatura')
    return df

func_temperatura = FunctionTransformer(aux_temperatura, check_inverse=False)

# %%
# feature: visibilidade
top_visibilidade = 0.35


def aux_visibilidade(df):
    
    df.loc[df['visibilidade']>top_visibilidade] = top_visibilidade
    print('auxiliar visibilidade')
    return df

func_visibilidade = FunctionTransformer(aux_visibilidade, check_inverse=False)

# %%
# condições ideais
def aux_ideal(df):
    df['ideal'] = df[['temperatura', 'umidade', 'visibilidade', 'dia_util']].apply(lambda x: (0, 1)[x['temperatura'] > 27 and x['umidade'] > 75  and x['visibilidade'] < 0.35  and x['dia_util']==1], axis = 1)
    return df[['ideal']]

func_ideal = FunctionTransformer(aux_ideal, check_inverse=False)

# %% [markdown]
# * Função para não alterar nada, retornando o mesmo valor de entrada

# %%
def aux_no_change(df):
    print('no change', df.shape)
    return df


no_change = FunctionTransformer(aux_no_change)
  

    
# transformer mixin : https://stackoverflow.com/questions/46162855/fit-transform-takes-2-positional-arguments-but-3-were-given-with-labelbinarize

# %% [markdown]
# # Transformações do SKlearn

# %%
# Numerical transformations
max_abs = MaxAbsScaler()
sc = StandardScaler()
min_max = MinMaxScaler()
robust = RobustScaler() 
norma = Normalizer()
quanti_uni = QuantileTransformer(output_distribution='uniform')
quanti_norm = QuantileTransformer(output_distribution='normal')
box_cox = PowerTransformer(method = 'box-cox')
log1 = FunctionTransformer(np.log1p, check_inverse=False)
log = FunctionTransformer(np.log, check_inverse=False) 


poly = PolynomialFeatures(degree=2, 
                          interaction_only = True,
                          include_bias = False
                         )

# Categorical encoders
bi_encoder = ce.BinaryEncoder()
target_encoder = ce.target_encoder.TargetEncoder()
out_encoder = ce.leave_one_out.LeaveOneOutEncoder() 
median_encoder = ce.quantile_encoder.QuantileEncoder()

def aux_one_hot(df):
    print('one hot', df.shape)
    return df.iloc[:,:-1]
func_one_hot = FunctionTransformer(aux_one_hot)
  
one_hot = Pipeline(    steps = [
    ("trans", ce.one_hot.OneHotEncoder(return_df=True)),
    ("encode", func_one_hot),  
])

one_hot = ce.one_hot.OneHotEncoder(return_df=True)

one_hot = OneHotEncoder(drop = 'first')
# Out:
# C:\Users\camil\AppData\Roaming\Python\Python38\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\camil\AppData\Roaming\Python\Python38\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."

# %% [markdown]
# # Criando o pipeline

# %%
# Transformações para adicionar colunas na df

# Período do dia
periodo_dia_pipeline = Pipeline(
    steps = [
        ("trans", func_periodo_dia),
        ("encode", one_hot),  # out_encoder, one_hot
        ])

prep_periodo_dia = ColumnTransformer([('periodo_dia', periodo_dia_pipeline, ['hora']),                                                     
                                 ], 
                                remainder='drop',
                                    )

# Dia útil
prep_dia_util = ColumnTransformer([('dia_util', func_dia_util, ['dia', 'feriado']),                                                     
                                 ], 
                                remainder='drop')

# Pico da manhã
prep_horas_pico_manha = ColumnTransformer([('pico_manha', func_pico_manha, ['hora']),                                                     
                                 ], 
                                remainder='drop')

# Pico da tarde
prep_horas_pico_tarde = ColumnTransformer([('pico_tarde', func_pico_tarde, ['hora']),                                                     
                                 ], 
                                remainder='drop')

# máximos dos picos
prep_horas_picos = ColumnTransformer([('picos', func_picos, ['hora', 'dia_util', 'dia']),                                                     
                                 ], 
                                remainder='drop')

# Horas vale
prep_horas_vale = ColumnTransformer([('horas_vale', func_horas_vale, ['hora']),                                                     
                                 ], 
                                remainder='drop')


# Transformações nas colunas previamente existentes

estacao_pipeline = Pipeline(
    steps = [
        ("trans", ce.ordinal.OrdinalEncoder()),
        ("encode", out_encoder),  # out_encoder, no_change ou one_hot
        ])

temp_pipeline = Pipeline(
    steps = [
        ("trans", no_change), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])

chuva_pipeline = Pipeline(
    steps = [
        ("trans", no_change), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])

umidade_pipeline = Pipeline(
    steps = [
        ("trans", no_change), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])

sol_pipeline = Pipeline(
    steps = [
        ("trans", no_change), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])

visibilidade_pipeline = Pipeline(
    steps = [
        ("trans", no_change), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])

vento_pipeline = Pipeline(
    steps = [
        ("trans", func_vento), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])


prep_colunas = ColumnTransformer([('hora', out_encoder, ['hora']), # out_encoder, one_hot, no_change, spline
                                  ('dia', out_encoder, ['dia']), 
                                  ('estacao', estacao_pipeline , ['estação']),
                                  ('temperatura', temp_pipeline,['temperatura']),  
                                  ('chuva', chuva_pipeline,['chuva']),      
                                  ('umidade', umidade_pipeline,['umidade']),  
                                  ('sol', sol_pipeline,['sol']),          
                                  ('visibilidade', visibilidade_pipeline, ['visibilidade']),  
                                  ('vento', vento_pipeline, ['vento']),                                                       
                                 ], 
                                remainder='passthrough',
                                #sparse_threshold = 0, 
                                 verbose=True)

prep_inverso = ColumnTransformer([
                                  ('temperatura', func_inverso,['temperatura']),  
                                     
                                  ('umidade', func_inverso,['umidade']),  
                                         
                                  ('visibilidade', func_inverso, ['visibilidade']),  
                                  ('vento', func_inverso, ['vento']),                                                       
                                 ], 
                                remainder='drop',
                                #sparse_threshold = 0, 
                                 verbose=True)

prep_raiz = ColumnTransformer([
                                  ('temperatura', func_raiz,['temperatura']),  
                                  ('chuva', func_raiz,['chuva']),      
                                  ('umidade', func_raiz,['umidade']),  
                                  ('sol', func_raiz,['sol']),          
                                  ('visibilidade', func_raiz, ['visibilidade']),  
                                  ('vento', func_raiz, ['vento']),                                                       
                                 ], 
                                remainder='drop',
                                #sparse_threshold = 0, 
                                 verbose=True)

prep_inverso_raiz = ColumnTransformer([
                                  ('temperatura', func_inverso_raiz,['temperatura']),  
                          
                                  ('umidade', func_inverso_raiz,['umidade']),  
              
                                  ('visibilidade', func_inverso_raiz, ['visibilidade']),  
                                  ('vento', func_inverso_raiz, ['vento']),                                                       
                                 ], 
                                remainder='drop',
                                #sparse_threshold = 0, 
                                 verbose=True)



# Unindo as transformações criadas acima
uniao = FeatureUnion([('ct1', prep_periodo_dia), 
                      ('ct2', prep_dia_util),
                      ('ct3', prep_horas_pico_manha),
                      ('ct4', prep_horas_pico_tarde),
                      ('ct5', prep_horas_picos),
                      ('ct6', prep_horas_vale),
                      ('ct7', prep_colunas),
                     # ('ct8', prep_inverso),
                     # ('ct9', prep_raiz),
                     # ('ct10', prep_inverso_raiz)
                     ], verbose=True)


preprocessor = Pipeline(steps=[
    ("uniao", uniao),
    ('poly', PolynomialFeatures(degree=2, interaction_only = True, include_bias = False)),
                               
                              ],
                       verbose=True)

lgbm = LGBMRegressor()

pipe_model = Pipeline(steps=[('prep', preprocessor), ('modelo', lgbm)])

pipe_final = TransformedTargetRegressor(regressor=pipe_model,
                                   transformer = StandardScaler())

# %% [markdown]
# # Definindo os parâmetros para o Random Search

# %%
import scipy.stats.distributions as dists

param_grid = [{
    # periodo do dia
    #'regressor__prep__uniao__ct1': [no_change, prep_periodo_dia],     
    
    # dia útil
    #'regressor__prep__uniao__ct2': [no_change, prep_dia_util],    
    
    # horas pico manhã
    #'regressor__prep__uniao__ct3': [no_change, prep_horas_pico_manha],
    
    # horas pico tarde
    #'regressor__prep__uniao__ct4': [no_change, prep_horas_pico_tarde],
    
    # máximas horas de pico
    #'regressor__prep__uniao__ct5': [no_change, prep_horas_picos],
    
    # horas vale
    #'regressor__prep__uniao__ct6': [no_change, prep_horas_vale],  
    
    
    
    # coluna hora
    'regressor__prep__uniao__ct7__hora': [out_encoder, one_hot, no_change,  #spline_hora
                                         ],             
    
    # coluna dia        
    'regressor__prep__uniao__ct7__dia': [out_encoder, no_change, one_hot,  # spline_dia
                                                ],
    
    # coluna estação
    'regressor__prep__uniao__ct7__estacao': [out_encoder, one_hot],
        
    # coluna temperatura        
    'regressor__prep__uniao__ct7__temperatura': [no_change,sc, min_max, log1, max_abs, robust, func_raiz, func_inverso_raiz, func_inverso],
   # 'regressor__prep__ct7__temperatura__scaler': [sc, min_max, log1, max_abs, robust, no_change],
    
    # coluna chuva
    'regressor__prep__uniao__ct7__chuva': [no_change, sc, min_max, log1, max_abs, robust, func_raiz],
    #'regressor__prep__ct7__chuva__scaler': [sc, min_max, log1, max_abs, robust, no_change],
    
    # coluna umidade
    'regressor__prep__uniao__ct7__umidade': [no_change, sc, min_max, log1, max_abs, robust, func_raiz, func_inverso_raiz, func_inverso],
    #'regressor__prep__ct7__umidade__scaler': [sc, min_max, log1, max_abs, robust, no_change],
    
    # coluna sol
    'regressor__prep__uniao__ct7__sol': [no_change, sc, min_max, log1, max_abs, robust, func_raiz],
    #'regressor__prep__ct7__sol__scaler': [sc, min_max, log1, max_abs, robust, no_change],
    
    # coluna visibilidade,
    'regressor__prep__uniao__ct7__visibilidade': [no_change, sc, min_max, log1, max_abs, robust, func_raiz, func_inverso_raiz, func_inverso],
    #'regressor__prep__ct7__visibilidade__scaler': [sc, min_max, log1, max_abs, robust, no_change],
    
    # coluna vento
    'regressor__prep__uniao__ct7__vento__trans': [no_change, func_vento],
    'regressor__prep__uniao__ct7__vento__scaler': [no_change, sc, min_max, log1, max_abs, robust, func_raiz, func_inverso_raiz, func_inverso],
    #'regressor__prep__ct7__vento__scaler': [sc, min_max, log1, max_abs, robust, no_change],
    
    
    
    # Polynomial Transformer    
    'regressor__prep__poly__interaction_only': [True, False],
    
    
    
    # Parámetros do modelo de regressão LGBM
    'regressor__modelo__reg_alpha': dists.loguniform(1e-8,10,loc=0, scale=1),
    'regressor__modelo__reg_lambda': dists.loguniform(1e-8,10,loc=0, scale=1),
    'regressor__modelo__num_leaves': dists.randint(low=2, high=256),
    'regressor__modelo__colsample_bytree': dists.uniform(loc=0.4, scale=0.6),
    
    'regressor__modelo__subsample': dists.uniform(loc=0.4, scale=0.6),
    'regressor__modelo__subsample_freq': dists.randint(low=1, high=7),
    'regressor__modelo__min_child_samples': dists.randint(low=5, high=100),
    'regressor__modelo__min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
    
    'regressor__modelo__max_depth': dists.randint(low=6, high=18),
    'regressor__modelo__learning_rate': dists.triang(loc=0.008, c = 0.1, scale=0.18),
    'regressor__modelo__n_estimators':  dists.randint(low=100, high=800),
    'regressor__modelo__min_split_gain': dists.loguniform(1e-8,15,loc=0, scale=1),
    'regressor__modelo__random_state': [1986],
    
    
    # Alterando as transformações na variável target
    'transformer': [sc, box_cox, robust, min_max, max_abs, no_change],
    


    
    }]

# %% [markdown]
# ## Funções úteis

# %%
def rmse_eval(df, modelo, kf = KFold(n_splits = 15, random_state = 1986)):

    X = df.drop(columns = ['aluguéis'], axis = 1)
    y = df['aluguéis']

    scTreino = [] 
    scTeste = [] 

    df_treino = df.copy()

    for i_treino,i_teste in kf.split(X): 
        X_treino, y_treino = X.iloc[i_treino],y.iloc[i_treino] 
        X_teste, y_teste = X.iloc[i_teste],y.iloc[i_teste] 
        pipe_final.fit(X_treino,y_treino) 
        y_predTreino = pipe_final.predict(X_treino) 
        y_predTeste = pipe_final.predict(X_teste) 
        df_treino.loc[i_teste,'preditos'] = y_predTeste
        scTreino.append(np.sqrt(mean_squared_error(y_treino,y_predTreino))) 
        scTeste.append(np.sqrt(mean_squared_error(y_teste,y_predTeste))) 

    print("RSME treino e: {:.2f}, std: {:.2f}".format(np.mean(scTreino), np.std(scTreino))) 
    print("RSME teste  e: {:.2f}, std: {:.2f}".format(np.mean(scTeste), np.std(scTeste))) 
    
    df_treino['dif'] = df_treino['aluguéis'] - df_treino.preditos
    df_treino['abs_dif'] = abs(df_treino['aluguéis'] - df_treino.preditos)
    df_treino['erro_quadra'] = df_treino['abs_dif'].pow(2)
    
    return df_treino

def erro_groupby(df, coluna):
    
    df_analise = df.copy()
    
    df_analise = df_analise.groupby(coluna)['erro_quadra', 'abs_dif'].mean()
    df_analise['erro_quadra'] = np.sqrt(df_analise['erro_quadra'])
    
    return df_analise

# %% [markdown]
# # Random Search

# %%
df = treino.copy()  
    
X = df.drop(columns = ['aluguéis'], axis = 1)
y = df['aluguéis']


kf = KFold(n_splits = 5)

grid_search_pipe = RandomizedSearchCV(pipe_final    ,
                             param_grid,
                             cv=kf,
                             scoring='neg_mean_squared_error',
                             verbose=11,
                             n_jobs=-1,
                             n_iter=500,
                             return_train_score = True,          
                            )
grid_search_pipe.fit(X,y)      

resultados = pd.DataFrame(grid_search_pipe.cv_results_)
resultados.mean_test_score = np.sqrt(abs(resultados.mean_test_score))
resultados.mean_train_score = np.sqrt(abs(resultados.mean_train_score))
resultados = resultados.sort_values(by = 'rank_test_score')
display(resultados)
    
print(np.sqrt(abs(grid_search_pipe.best_score_)))
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   43.9s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   46.5s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 499 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 500 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 501 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 502 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 507 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 509 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 510 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 513 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 515 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 516 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 517 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 518 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 519 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 523 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 524 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 525 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 526 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 527 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 531 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 532 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 533 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 534 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 535 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 536 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 540 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 541 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 542 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 545 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 547 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 548 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 549 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 550 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 551 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 553 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 554 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 555 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 557 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 559 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 560 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 561 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 562 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 563 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 564 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 566 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 567 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 569 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 571 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 572 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 574 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 575 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 576 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 578 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 579 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 581 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 582 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 583 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 585 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 586 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 587 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 588 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 589 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 590 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 591 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 592 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 593 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 594 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 595 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 598 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 599 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 600 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 601 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 603 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 604 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 606 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 609 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 611 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 612 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 613 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 614 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 615 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 617 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 618 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 619 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 620 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 621 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 622 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 623 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 625 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 626 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 627 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 628 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 629 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 630 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 631 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 633 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 634 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 635 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 636 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 637 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 638 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 639 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 641 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 642 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 643 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 646 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 647 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 651 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 652 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 653 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 654 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 655 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 657 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 658 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 659 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 660 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 661 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 662 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 663 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 665 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 666 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 667 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 668 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 669 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 670 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 671 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 673 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 675 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 676 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 678 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 679 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 680 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 681 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 683 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 684 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 685 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 686 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 687 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 689 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 690 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 691 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 692 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 694 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 695 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 697 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 698 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 699 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 700 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 701 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 702 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 703 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 704 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 705 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 707 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 708 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 709 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 710 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 711 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 712 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 713 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 715 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 716 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 717 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 718 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 719 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 720 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 722 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 723 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 724 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 725 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 726 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 727 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 728 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 729 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 730 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 731 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 732 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 733 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 734 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 735 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 736 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 737 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 738 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 739 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 740 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 741 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 742 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 743 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 744 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 745 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 746 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 747 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 748 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 749 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 750 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 751 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 754 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 755 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 756 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 757 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 758 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 759 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 760 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 761 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 762 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 763 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 764 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 765 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 766 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 767 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 768 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 769 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 770 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 771 tasks      | elapsed: 16.4min
# ...
# [Parallel(n_jobs=-1)]: Done 2428 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 2429 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 2430 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 2431 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 2432 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 2433 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2435 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2436 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2437 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2438 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2439 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2440 tasks      | elapsed: 47.8min
# [Parallel(n_jobs=-1)]: Done 2441 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2443 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2444 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2445 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2446 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2447 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 2448 tasks      | elapsed: 48.0min
# [Parallel(n_jobs=-1)]: Done 2449 tasks      | elapsed: 48.0min
# [Parallel(n_jobs=-1)]: Done 2450 tasks      | elapsed: 48.0min
# [Parallel(n_jobs=-1)]: Done 2451 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 2452 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 2453 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 2454 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 2455 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 2456 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2457 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2458 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2459 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2460 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2461 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2462 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2463 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 2464 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2465 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2466 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2467 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2468 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2469 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2470 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 2471 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2472 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2473 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2474 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2475 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2476 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2477 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2478 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2479 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 2480 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2481 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2482 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2483 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2484 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2485 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2486 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2487 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2488 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2489 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2490 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 2491 tasks      | elapsed: 48.6min
# [Parallel(n_jobs=-1)]: Done 2492 tasks      | elapsed: 48.6min
# [Parallel(n_jobs=-1)]: Done 2493 tasks      | elapsed: 48.6min
# [Parallel(n_jobs=-1)]: Done 2500 out of 2500 | elapsed: 48.7min finished
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.3s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.4s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4500, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4500, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.1s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.9s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 432       9.764839      0.053694         0.451727        0.033491
# 52        7.040711      0.313111         0.327819        0.037786
# 434       3.424639      0.156007         0.296538        0.017340
# 26        4.099700      0.066850         0.315551        0.022959
# 228       3.085473      0.055269         0.311615        0.023659
# ..             ...           ...              ...             ...
# 303       1.937628      0.082624         0.271822        0.035086
# 470       2.614561      0.103070         0.212702        0.015539
# 382       1.543719      0.057214         0.206553        0.011812
# 174       2.139870      0.463144         0.212889        0.009029
# 499       1.746535      0.024958         0.209325        0.007652
#
#     param_regressor__modelo__colsample_bytree  \
# 432                                  0.573099
# 52                                   0.477877
# 434                                  0.570898
# 26                                   0.668983
# 228                                  0.471623
# ..                                        ...
# 303                                  0.555681
# 470                                  0.482818
# 382                                  0.599817
# 174                                  0.425257
# 499                                  0.843514
#
#     param_regressor__modelo__learning_rate param_regressor__modelo__max_depth  \
# 432                               0.027359                                 16
# 52                                0.064228                                 11
# 434                               0.093392                                 15
# 26                                0.070534                                  9
# 228                               0.092158                                  7
# ..                                     ...                                ...
# 303                               0.042212                                 11
# 470                               0.139546                                  7
# 382                               0.063685                                 14
# 174                                0.06872                                 12
# 499                               0.108048                                 14
#
#     param_regressor__modelo__min_child_samples  \
# 432                                         17
# 52                                           5
# 434                                         40
# 26                                          51
# 228                                         17
# ..                                         ...
# 303                                         94
# 470                                         37
# 382                                         29
# 174                                         90
# 499                                         18
#
#     param_regressor__modelo__min_child_weight  \
# 432                                      10.0
# 52                                       0.01
# 434                                      10.0
# 26                                       0.01
# 228                                      10.0
# ..                                        ...
# 303                                   10000.0
# 470                                   10000.0
# 382                                    1000.0
# 174                                   10000.0
# 499                                   10000.0
#
#     param_regressor__modelo__min_split_gain  \
# 432                                0.000038
# 52                                 0.000886
# 434                                0.000009
# 26                                 0.000014
# 228                                0.001203
# ..                                      ...
# 303                                     0.0
# 470                                     0.0
# 382                                0.025052
# 174                                     0.0
# 499                                     0.0
#
#     param_regressor__modelo__n_estimators param_regressor__modelo__num_leaves  \
# 432                                   795                                 218
# 52                                    427                                  44
# 434                                   522                                 101
# 26                                    630                                 189
# 228                                   692                                 217
# ..                                    ...                                 ...
# 303                                   365                                  45
# 470                                   649                                 182
# 382                                   513                                 100
# 174                                   688                                 211
# 499                                   283                                 252
#
#     param_regressor__modelo__random_state param_regressor__modelo__reg_alpha  \
# 432                                  1986                            2.70502
# 52                                   1986                           0.000397
# 434                                  1986                           1.101106
# 26                                   1986                           0.735385
# 228                                  1986                           0.000165
# ..                                    ...                                ...
# 303                                  1986                           8.054538
# 470                                  1986                                0.0
# 382                                  1986                                0.0
# 174                                  1986                             0.0641
# 499                                  1986                                0.0
#
#     param_regressor__modelo__reg_lambda  ... split0_test_score  \
# 432                            0.076022  ...     -67692.594602
# 52                             0.000003  ...     -69907.598318
# 434                            0.016042  ...     -69690.863908
# 26                             0.836711  ...     -72816.605707
# 228                             0.49203  ...     -73445.945113
# ..                                  ...  ...               ...
# 303                            0.000988  ...    -960437.715843
# 470                                 0.0  ...    -960437.715843
# 382                            0.001781  ...    -960437.715843
# 174                            0.000001  ...    -960437.715843
# 499                             4.28737  ...    -960437.715843
#
#     split1_test_score split2_test_score split3_test_score split4_test_score  \
# 432     -93363.351161     -66687.643084     -70690.657085     -51873.786617
# 52      -96042.573001     -69890.349921     -71234.735046     -55837.491926
# 434     -97602.080571     -74957.491055     -76167.807947     -53476.858699
# 26      -96362.828969     -73028.117354     -75612.363535     -55443.199547
# 228     -97483.787868     -74292.870697     -74479.393137     -56465.344842
# ..                ...               ...               ...               ...
# 303    -894521.956584    -917448.609705    -985796.560056    -933784.004891
# 470    -894521.956584    -917448.609705    -985796.560056    -933784.004891
# 382    -894521.956584    -917448.609705    -985796.560056    -933784.004891
# 174    -894521.956584    -917448.609705    -985796.560056    -933784.004891
# 499    -894521.956584    -917448.609705    -985796.560056    -933784.004891
#
#     mean_test_score std_test_score rank_test_score split0_train_score  \
# 432      264.691531   13350.353160               1       -9461.799167
# 52       269.411488   13015.295325               2       -1358.825530
# 434      272.725174   14154.321516               3      -20424.507397
# 26       273.226322   13017.419657               4      -16026.851859
# 228      274.287200   13053.488203               5       -8124.658487
# ..              ...            ...             ...                ...
# 303      968.709332   31992.641842             493     -932878.679999
# 470      968.709332   31992.641842             493     -932878.679999
# 382      968.709332   31992.641842             493     -932878.679999
# 174      968.709332   31992.641842             493     -932878.679999
# 499      968.709332   31992.641842             493     -932878.679999
#
#     split1_train_score split2_train_score split3_train_score  \
# 432       -9445.440702       -9668.451942       -9341.746815
# 52        -1368.281566       -1399.543465       -1373.062281
# 434      -20216.775195      -19578.307853      -20104.628271
# 26       -15162.765969      -14782.197549      -15891.310359
# 228       -8102.916893       -8070.603986       -8763.290687
# ..                 ...                ...                ...
# 303     -949353.098155     -943630.288660     -926566.201117
# 470     -949353.098155     -943630.288660     -926566.201117
# 382     -949353.098155     -943630.288660     -926566.201117
# 174     -949353.098155     -943630.288660     -926566.201117
# 499     -949353.098155     -943630.288660     -926566.201117
#
#     split4_train_score mean_train_score std_train_score
# 432       -9756.242704        97.645974      153.286288
# 52        -1449.096019        37.279509       32.599257
# 434      -21987.160993       143.046412      811.946173
# 26       -16356.528370       125.075700      581.330245
# 228       -8637.304114        91.322258      297.563109
# ..                 ...              ...             ...
# 303     -939559.456542       968.709216     7989.923135
# 470     -939559.456542       968.709216     7989.923135
# 382     -939559.456542       968.709216     7989.923135
# 174     -939559.456542       968.709216     7989.923135
# 499     -939559.456542       968.709216     7989.923135
#
# [500 rows x 45 columns]
# 264.6915308610537

# %%
grid_best.regressor_[1]
# Out:
# LGBMRegressor(colsample_bytree=0.573099425153106,
#               learning_rate=0.02735933533082987, max_depth=16,
#               min_child_samples=17, min_child_weight=10.0,
#               min_split_gain=3.832627927552628e-05, n_estimators=795,
#               num_leaves=218, random_state=1986, reg_alpha=2.7050201034653627,
#               reg_lambda=0.07602219372259673, subsample=0.7696869993717743,
#               subsample_freq=2)

# %%
params = {'regressor__modelo__colsample_bytree': 0.573099425153106, 
           'regressor__modelo__learning_rate': 0.02735933533082987, 
           'regressor__modelo__max_depth': 16, 
           'regressor__modelo__min_child_samples': 17, 
           'regressor__modelo__min_child_weight': 10.0, 
           'regressor__modelo__min_split_gain': 3.832627927552628e-05, 
           'regressor__modelo__n_estimators': 795, 
           'regressor__modelo__num_leaves': 218, 
           'regressor__modelo__random_state': 1986, 
           'regressor__modelo__reg_alpha': 2.7050201034653627, 
           'regressor__modelo__reg_lambda': 0.07602219372259673, 
           'regressor__modelo__subsample': 0.7696869993717743, 
           'regressor__modelo__subsample_freq': 2, 
           'regressor__prep__poly__interaction_only': True, 
           'regressor__prep__uniao__ct7__chuva': StandardScaler(), 
           'regressor__prep__uniao__ct7__dia': no_change, 
           'regressor__prep__uniao__ct7__estacao': OneHotEncoder(drop='first'), 
           'regressor__prep__uniao__ct7__hora': no_change, 
           'regressor__prep__uniao__ct7__sol': func_raiz, 
           'regressor__prep__uniao__ct7__temperatura': func_raiz, 
           'regressor__prep__uniao__ct7__umidade': func_inverso, 
           'regressor__prep__uniao__ct7__vento__scaler': StandardScaler(), 
           'regressor__prep__uniao__ct7__vento__trans': func_vento, 
           'regressor__prep__uniao__ct7__visibilidade': log1, 
           'transformer': StandardScaler()}

# %%
SEED = 1986
np.random.seed(SEED)


grid_best = grid_search_pipe.best_estimator_.set_params(**params)
df_treino_one = rmse_eval(treino, grid_best)


# RSME teste  e: 258.39, std: 29.46
# Out:
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.1s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.4s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.1s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.4s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# RSME treino e: 96.04, std: 0.65
# RSME teste  e: 258.39, std: 29.46

# %%
erro_groupby(df_treino_one, 'estação')
# Out:
# <ipython-input-29-05a2a3747704>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_analise = df_treino_one.groupby('estação')['erro_quadra', 'abs_dif'].mean()
#          erro_quadra     abs_dif
# estação
# 1          77.803779   52.359051
# 2         234.827545  150.259562
# 3         371.874561  233.138761
# 4         260.232834  165.964567

# %%
erro_groupby(df_treino_one, 'dia')
# Out:
# <ipython-input-168-f1ba706f63d1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_analise = df_treino_one.groupby('dia')['erro_quadra', 'abs_dif'].mean()
#      erro_quadra     abs_dif
# dia
# 1     327.238826  200.785184
# 2     236.839312  138.233929
# 3     285.285587  158.705883
# 4     234.106594  139.065601
# 5     227.863262  137.829033
# 6     257.632709  151.848711
# 7     235.144493  137.078055

# %%
erro_groupby(df_treino_one, 'hora')
# Out:
# <ipython-input-169-491dba82a78e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_analise = df_treino_one.groupby('hora')['erro_quadra', 'abs_dif'].mean()
#       erro_quadra     abs_dif
# hora
# 0      155.728892  100.886549
# 1      128.903799   95.869541
# 2      106.809209   74.648047
# 3       75.471061   52.721923
# 4       55.439143   38.213855
# 5       49.259737   34.769774
# 6      125.107703   90.031752
# 7      304.513796  213.354317
# 8      513.274691  389.149574
# 9      215.286001  148.702693
# 10     170.336122  105.323476
# 11     159.032625  101.727442
# 12     174.098231  102.457162
# 13     213.890553  126.723982
# 14     262.422596  155.710777
# 15     291.495537  185.366578
# 16     290.412536  178.519305
# 17     280.330470  182.817142
# 18     554.846702  382.406817
# 19     332.650711  220.679236
# 20     250.661377  162.391096
# 21     275.055466  175.222596
# 22     282.631986  180.858525
# 23     212.128080  136.699041

# %%
df_treino_one.describe()
# Out:
#               hora          dia      feriado      estação  temperatura  \
# count  4500.000000  4500.000000  4500.000000  4500.000000  4500.000000
# mean     11.644889     3.972444     0.049778     2.527111    27.108356
# std       6.901146     1.976669     0.217510     1.110048     7.976684
# min       0.000000     1.000000     0.000000     1.000000     6.500000
# 25%       6.000000     2.000000     0.000000     2.000000    20.900000
# 50%      12.000000     4.000000     0.000000     3.000000    27.800000
# 75%      18.000000     6.000000     0.000000     4.000000    33.500000
# max      23.000000     7.000000     1.000000     4.000000    44.600000
#
#              chuva      umidade          sol  visibilidade        vento  \
# count  4500.000000  4500.000000  4500.000000   4500.000000  4500.000000
# mean      0.161864    62.087133     0.578104      0.696940     2.322933
# std       1.179291    15.176118     0.878158      0.296047     1.243427
# min       0.000000    18.100000     0.000000      0.020000     0.250000
# 25%       0.000000    50.500000     0.000000      0.450000     1.330000
# 50%       0.000000    61.100000     0.010000      0.830000     2.050000
# 75%       0.000000    73.900000     0.940000      0.970000     3.010000
# max      27.650000    92.000000     3.520000      0.970000     9.130000
#
#           aluguéis     dia_util     preditos          dif      abs_dif  \
# count  4500.000000  4500.000000  4500.000000  4500.000000  4500.000000
# mean    727.169556     0.689333   726.772599     0.396957   151.997425
# std     646.886075     0.462818   589.703707   260.095353   211.048331
# min       5.000000     0.000000   -45.199793 -2287.679031     0.021776
# 25%     208.750000     0.000000   243.773640   -75.117696    30.986269
# 50%     534.500000     1.000000   562.113089    -2.028427    79.235835
# 75%    1096.000000     1.000000  1068.645301    83.222848   179.534604
# max    3566.000000     1.000000  3159.896101  1425.882888  2287.679031
#
#         erro_quadra
# count  4.500000e+03
# mean   6.763472e+04
# std    2.418077e+05
# min    4.741998e-04
# 25%    9.601489e+02
# 50%    6.278322e+03
# 75%    3.223267e+04
# max    5.233475e+06

# %%
np.sqrt(df_treino_one.erro_quadra.mean())
# Out:
# 260.0667550460558

# %% [markdown]
# # Modelo 11

# %%
# Período do dia
periodo_dia_pipeline = Pipeline(
    steps = [
        ("trans", func_periodo_dia),
        ("encode", one_hot),  # out_encoder, one_hot
        ])

prep_periodo_dia = ColumnTransformer([('periodo_dia', periodo_dia_pipeline, ['hora']),                                                     
                                 ], 
                                remainder='drop',
                                    )

# Dia útil
prep_dia_util = ColumnTransformer([('dia_util', func_dia_util, ['dia', 'feriado']),                                                     
                                 ], 
                                remainder='drop')

# Pico da manhã
prep_horas_pico_manha = ColumnTransformer([('pico_manha', func_pico_manha, ['hora']),                                                     
                                 ], 
                                remainder='drop')

# Pico da tarde
prep_horas_pico_tarde = ColumnTransformer([('pico_tarde', func_pico_tarde, ['hora']),                                                     
                                 ], 
                                remainder='drop')

# máximos dos picos
prep_horas_picos = ColumnTransformer([('picos', func_picos, ['hora', 'dia_util', 'dia']),                                                     
                                 ], 
                                remainder='drop')

# Horas vale
prep_horas_vale = ColumnTransformer([('horas_vale', func_horas_vale, ['hora']),                                                     
                                 ], 
                                remainder='drop')


# Transformações nas colunas previamente existentes

vento_pipeline = Pipeline(
    steps = [
        ("trans", func_vento), # func_inverso, func_raiz, func_inverso_raiz, no_change
        ("scaler", sc),  #
        ])


prep_colunas = ColumnTransformer([('hora', no_change, ['hora']), # out_encoder, one_hot, no_change, spline
                                  ('dia', no_change, ['dia']), 
                                  ('estacao', one_hot , ['estação']),
                                  ('temperatura', func_raiz,['temperatura']),  
                                  ('chuva', sc,['chuva']),      
                                  ('umidade', func_inverso,['umidade']),  
                                  ('sol', func_raiz,['sol']),          
                                  ('visibilidade', log1, ['visibilidade']),  
                                  ('vento', vento_pipeline, ['vento']),                                                       
                                 ], 
                                remainder='passthrough',
                                #sparse_threshold = 0, 
                                 verbose=True)


# Unindo as transformações criadas acima
uniao = FeatureUnion([('ct1', prep_periodo_dia), 
                      ('ct2', prep_dia_util),
                      ('ct3', prep_horas_pico_manha),
                      ('ct4', prep_horas_pico_tarde),
                      ('ct5', prep_horas_picos),
                      ('ct6', prep_horas_vale),
                      ('ct7', prep_colunas),
                     # ('ct8', prep_inverso),
                     # ('ct9', prep_raiz),
                     # ('ct10', prep_inverso_raiz)
                     ], verbose=True)


preprocessor = Pipeline(steps=[
    ("uniao", uniao),
    ('poly', PolynomialFeatures(degree=2, interaction_only = True, include_bias = False)),
                               
                              ],
                       verbose=True)

params_ = {'colsample_bytree': 0.573099425153106, 
           'learning_rate': 0.02735933533082987, 
           'max_depth': 16, 
           'min_child_samples': 17, 
           'min_child_weight': 10.0, 
           'min_split_gain': 3.832627927552628e-05, 
           'n_estimators': 795, 
           'num_leaves': 218, 
           'random_state': 1986, 
           'reg_alpha': 2.7050201034653627, 
           'reg_lambda': 0.07602219372259673, 
           'subsample': 0.7696869993717743, 
           'subsample_freq': 2, 
          }

lgbm = LGBMRegressor(**params_)

pipe_model = Pipeline(steps=[('prep', preprocessor), ('modelo', lgbm)])

pipe_final = TransformedTargetRegressor(regressor=pipe_model,
                                   transformer = StandardScaler())

# %%
SEED = 1986
np.random.seed(SEED)


X = treino.drop(columns = ['aluguéis'], axis = 1)
y = treino['aluguéis']

kf = KFold(n_splits = 15)

scTreino = [] 
scTeste = [] 

df_treino_one = treino.copy()




for i_treino,i_teste in kf.split(X): 
    X_treino, y_treino = X.iloc[i_treino],y.iloc[i_treino] 
    X_teste, y_teste = X.iloc[i_teste],y.iloc[i_teste] 
    pipe_final.fit(X_treino,y_treino) 
    y_predTreino = pipe_final.predict(X_treino) 
    y_predTeste = pipe_final.predict(X_teste) 
    df_treino_one.loc[i_teste,'preditos'] = y_predTeste
    scTreino.append(np.sqrt(mean_squared_error(y_treino,y_predTreino))) 
    scTeste.append(np.sqrt(mean_squared_error(y_teste,y_predTeste))) 
    
print("RSME treino e: {:.2f}, std: {:.2f}".format(np.mean(scTreino), np.std(scTreino))) 
print("RSME teste  e: {:.2f}, std: {:.2f}".format(np.mean(scTeste), np.std(scTeste)))
# Out:
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.3s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.6s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.3s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.6s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.3s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.6s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.3s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.4s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.8s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.3s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.3s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.7s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.4s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.3s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.2s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.5s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.2s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.4s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4200, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.7s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (4200, 1)
# no change (4200, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (300, 1)
# no change (300, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento
# RSME treino e: 96.04, std: 0.65
# RSME teste  e: 258.39, std: 29.46

# %%
df_treino_one.to_csv('df_treino_one_grid.csv', index = False)

# %%
np.sqrt(df_treino_one.erro_quadra.mean())
# Out:
# 260.0667550460558

# %%
np.sqrt(df_treino_one.loc[df_treino_one['estação'] != 1].erro_quadra.mean())
# Out:
# 294.2565817837772

# %%
df_treinando5 = treino.copy()
df_testando5 = teste.copy()

SEED = 1986
np.random.seed(SEED)


X_final3 = df_treinando5.drop(columns = ['aluguéis'], axis = 1)
y_final3 = df_treinando5['aluguéis']

pipe_final.fit(X_final3, y_final3)
preditos_final_5 = pipe_final.predict(df_testando5)

df_testando5['preditos7'] = preditos_final_5

df_testando5.to_csv('df_teste_grid_one.csv', index = False)
# Out:
# periodo do dia
# [FeatureUnion] ........... (step 1 of 7) Processing ct1, total=   0.0s
# dia util
# [FeatureUnion] ........... (step 2 of 7) Processing ct2, total=   0.3s
# pico manha
# [FeatureUnion] ........... (step 3 of 7) Processing ct3, total=   0.0s
# pico tarde
# [FeatureUnion] ........... (step 4 of 7) Processing ct4, total=   0.0s
# picos
# [FeatureUnion] ........... (step 5 of 7) Processing ct5, total=   0.4s
# vale
# [FeatureUnion] ........... (step 6 of 7) Processing ct6, total=   0.0s
# no change (4500, 1)
# [ColumnTransformer] ......... (1 of 10) Processing hora, total=   0.0s
# no change (4500, 1)
# [ColumnTransformer] .......... (2 of 10) Processing dia, total=   0.0s
# [ColumnTransformer] ...... (3 of 10) Processing estacao, total=   0.0s
# raiz  temperatura
# [ColumnTransformer] .. (4 of 10) Processing temperatura, total=   0.0s
# [ColumnTransformer] ........ (5 of 10) Processing chuva, total=   0.0s
# inverso  umidade
# [ColumnTransformer] ...... (6 of 10) Processing umidade, total=   0.0s
# raiz  sol
# [ColumnTransformer] .......... (7 of 10) Processing sol, total=   0.0s
# [ColumnTransformer] . (8 of 10) Processing visibilidade, total=   0.0s
# auxiliar vento
# [ColumnTransformer] ........ (9 of 10) Processing vento, total=   0.0s
# [ColumnTransformer] ... (10 of 10) Processing remainder, total=   0.0s
# [FeatureUnion] ........... (step 7 of 7) Processing ct7, total=   0.0s
# [Pipeline] ............. (step 1 of 2) Processing uniao, total=   0.7s
# [Pipeline] .............. (step 2 of 2) Processing poly, total=   0.0s
# periodo do dia
# dia util
# pico manha
# pico tarde
# picos
# vale
# no change (3000, 1)
# no change (3000, 1)
# raiz  temperatura
# inverso  umidade
# raiz  sol
# auxiliar vento

# %%
df_testando5
# Out:
#       hora  dia  feriado  estação  temperatura  chuva  umidade  sol  \
# 0       21    5        0        4         33.3   0.12     72.4  0.0
# 1        0    2        0        3         25.0   0.00     73.1  0.0
# 2        4    2        0        3         22.1   0.00     67.9  0.0
# 3        6    3        0        4         36.5   0.00     80.7  0.0
# 4       21    5        0        4         34.2   0.00     65.6  0.0
# ...    ...  ...      ...      ...          ...    ...      ...  ...
# 2995    23    7        0        2         18.5   0.00     46.8  0.0
# 2996    21    1        0        1         15.5   0.00     62.6  0.0
# 2997    23    6        0        1         22.0   0.00     78.4  0.0
# 2998     4    5        0        4         36.6   0.00     70.1  0.0
# 2999     5    5        0        2         30.9   0.00     91.2  0.0
#
#       visibilidade  vento  dia_util    preditos7
# 0             0.88   2.05         1   608.752623
# 1             0.34   0.85         1   529.713532
# 2             0.97   1.09         1   161.726900
# 3             0.53   1.93         1   536.957270
# 4             0.71   2.05         1  2239.565172
# ...            ...    ...       ...          ...
# 2995          0.92   0.49         0   395.259717
# 2996          0.60   3.85         0   174.728660
# 2997          0.13   3.49         1   320.330093
# 2998          0.97   1.45         1   242.877326
# 2999          0.94   1.33         1   191.389410
#
# [3000 rows x 12 columns]

# %%
df_treino_one
# Out:
#       hora  dia  feriado  estação  temperatura  chuva  umidade   sol  \
# 0       16    7        0        4         39.4    0.0     61.1  2.19
# 1       21    6        0        2         22.2    0.0     63.3  0.00
# 2       16    2        0        4         40.5    0.0     52.8  2.51
# 3        7    2        1        3         25.6    0.0     70.9  0.00
# 4        9    2        0        4         39.9    0.0     58.1  1.69
# ...    ...  ...      ...      ...          ...    ...      ...   ...
# 4495     6    6        0        4         30.4    0.0     84.5  0.03
# 4496    16    4        0        3         28.5    0.0     48.3  0.87
# 4497    15    6        0        2         35.1    0.0     37.0  2.20
# 4498    18    1        0        3         32.7    0.0     85.2  0.18
# 4499    15    3        0        1         22.8    0.0     54.3  0.39
#
#       visibilidade  vento  aluguéis  dia_util     preditos         dif  \
# 0             0.92   3.49      1318         0  1173.457155  144.542845
# 1             0.32   2.89       686         1   599.705361   86.294639
# 2             0.93   3.97       831         1  1003.956132 -172.956132
# 3             0.97   1.09        15         0   153.647722 -138.647722
# 4             0.62   1.09       865         1   997.553325 -132.553325
# ...            ...    ...       ...       ...          ...         ...
# 4495          0.13   1.57       723         1   575.560821  147.439179
# 4496          0.67   3.49      1151         1  1233.086555  -82.086555
# 4497          0.95   3.49      1321         1  1476.238909 -155.238909
# 4498          0.17   3.85       533         0   948.611031 -415.611031
# 4499          0.40   1.21       411         1   367.585397   43.414603
#
#          abs_dif    erro_quadra
# 0     144.542845   20892.634080
# 1      86.294639    7446.764699
# 2     172.956132   29913.823690
# 3     138.647722   19223.190680
# 4     132.553325   17570.384021
# ...          ...            ...
# 4495  147.439179   21738.311589
# 4496   82.086555    6738.202522
# 4497  155.238909   24099.118886
# 4498  415.611031  172732.529050
# 4499   43.414603    1884.827748
#
# [4500 rows x 16 columns]
